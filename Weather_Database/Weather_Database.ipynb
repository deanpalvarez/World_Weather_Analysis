# %%
import pandas as pd
import numpy as np

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 710

# %%
import requests
from configcopy import weather_api_key

# %%
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"

# %%
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1                                                      
# url = "http://api.openweathermap.org/data/2.5/find?q={city}&units=imperial"
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    print(city_url)

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except Exception as e:
        print(e)
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=kahului
# Processing Record 1 of Set 1 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=srednekolymsk
# Processing Record 2 of Set 1 | srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=hohhot
# Processing Record 3 of Set 1 | hohhot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=muravlenko
# Processing Record 4 of Set 1 | muravlenko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=ushuaia
# Processing Record 5 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=richards+bay
# Processing Record 6 of Set 1 | richards bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=kloulklubed
# Processing Record 7 of Set 1 | kloulklubed
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=albany
# Processing Record 8 of Set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=arraial+do+cabo
# Processing Record 9 of Set 1 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=carnarvon
# Processing Record 10 of Set 1 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=castro
# Processing Record 11 of Set 1 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=saint-georges
# Processing Record 12 of Set 1 | saint-georges
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=gamba
# Processing Record 13 of Set 1 | gamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=rikitea
# Processing Record 14 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=sioux+lookout
# Processing Record 15 of Set 1 | sioux lookout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=lethem
# Processing Record 16 of Set 1 | lethem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=mossendjo
# Processing Record 17 of Set 1 | mossendjo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=manta
# Processing Record 18 of Set 1 | manta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=georgetown
# Processing Record 19 of Set 1 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=yellowknife
# Processing Record 20 of Set 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=udachnyy
# Processing Record 21 of Set 1 | udachnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=sitka
# Processing Record 22 of Set 1 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=saldanha
# Processing Record 23 of Set 1 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=shangrao
# Processing Record 24 of Set 1 | shangrao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=la+ronge
# Processing Record 25 of Set 1 | la ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=souillac
# Processing Record 26 of Set 1 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=bredasdorp
# Processing Record 27 of Set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=umzimvubu
# Processing Record 28 of Set 1 | umzimvubu
# 'coord'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=busselton
# Processing Record 29 of Set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=iqaluit
# Processing Record 30 of Set 1 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=sentyabrskiy
# Processing Record 31 of Set 1 | sentyabrskiy
# 'coord'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=phan+rang
# Processing Record 32 of Set 1 | phan rang
# 'coord'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=puerto+ayora
# Processing Record 33 of Set 1 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=punta+arenas
# Processing Record 34 of Set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=khatanga
# Processing Record 35 of Set 1 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=saint+george
# Processing Record 36 of Set 1 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=mahebourg
# Processing Record 37 of Set 1 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=new+norfolk
# Processing Record 38 of Set 1 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=karaul
# Processing Record 39 of Set 1 | karaul
# 'coord'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=palabuhanratu
# Processing Record 40 of Set 1 | palabuhanratu
# 'coord'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=poum
# Processing Record 41 of Set 1 | poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=grand+gaube
# Processing Record 42 of Set 1 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=victoria
# Processing Record 43 of Set 1 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=east+london
# Processing Record 44 of Set 1 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=beloha
# Processing Record 45 of Set 1 | beloha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=provideniya
# Processing Record 46 of Set 1 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=kununurra
# Processing Record 47 of Set 1 | kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=chokurdakh
# Processing Record 48 of Set 1 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=yuncheng
# Processing Record 49 of Set 1 | yuncheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=maxixe
# Processing Record 50 of Set 1 | maxixe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=mataura
# Processing Record 1 of Set 2 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=leningradskiy
# Processing Record 2 of Set 2 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=kapaa
# Processing Record 3 of Set 2 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=atuona
# Processing Record 4 of Set 2 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=hermanus
# Processing Record 5 of Set 2 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=coffs+harbour
# Processing Record 6 of Set 2 | coffs harbour
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=vestmannaeyjar
# Processing Record 7 of Set 2 | vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=attawapiskat
# Processing Record 8 of Set 2 | attawapiskat
# 'coord'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=remedios
# Processing Record 9 of Set 2 | remedios
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=the+pas
# Processing Record 10 of Set 2 | the pas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=luderitz
# Processing Record 11 of Set 2 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=asfi
# Processing Record 12 of Set 2 | asfi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=kaitangata
# Processing Record 13 of Set 2 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=socorro
# Processing Record 14 of Set 2 | socorro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=olinda
# Processing Record 15 of Set 2 | olinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=guerrero+negro
# Processing Record 16 of Set 2 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=labrea
# Processing Record 17 of Set 2 | labrea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=bluff
# Processing Record 18 of Set 2 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=marcona
# Processing Record 19 of Set 2 | marcona
# 'coord'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=marsaxlokk
# Processing Record 20 of Set 2 | marsaxlokk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=teguise
# Processing Record 21 of Set 2 | teguise
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=hamilton
# Processing Record 22 of Set 2 | hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=port+alfred
# Processing Record 23 of Set 2 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=thompson
# Processing Record 24 of Set 2 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=talnakh
# Processing Record 25 of Set 2 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=odienne
# Processing Record 26 of Set 2 | odienne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=dunedin
# Processing Record 27 of Set 2 | dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=kutum
# Processing Record 28 of Set 2 | kutum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=jamestown
# Processing Record 29 of Set 2 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=asosa
# Processing Record 30 of Set 2 | asosa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=kota+bahru
# Processing Record 31 of Set 2 | kota bahru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=port+macquarie
# Processing Record 32 of Set 2 | port macquarie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=sao+felix+do+xingu
# Processing Record 33 of Set 2 | sao felix do xingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=yulara
# Processing Record 34 of Set 2 | yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=constitucion
# Processing Record 35 of Set 2 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=taksimo
# Processing Record 36 of Set 2 | taksimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=kautokeino
# Processing Record 37 of Set 2 | kautokeino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=dingle
# Processing Record 38 of Set 2 | dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=butaritari
# Processing Record 39 of Set 2 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=cape+town
# Processing Record 40 of Set 2 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=hilo
# Processing Record 41 of Set 2 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=barentsburg
# Processing Record 42 of Set 2 | barentsburg
# 'coord'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=fairbanks
# Processing Record 43 of Set 2 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=porto+torres
# Processing Record 44 of Set 2 | porto torres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=illoqqortoormiut
# Processing Record 45 of Set 2 | illoqqortoormiut
# 'coord'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=kaabong
# Processing Record 46 of Set 2 | kaabong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=vaitupu
# Processing Record 47 of Set 2 | vaitupu
# 'coord'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=bethel
# Processing Record 48 of Set 2 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=tilichiki
# Processing Record 49 of Set 2 | tilichiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=floro
# Processing Record 50 of Set 2 | floro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=pangnirtung
# Processing Record 1 of Set 3 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=ancud
# Processing Record 2 of Set 3 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=nemuro
# Processing Record 3 of Set 3 | nemuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=piacabucu
# Processing Record 4 of Set 3 | piacabucu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=hambantota
# Processing Record 5 of Set 3 | hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=romny
# Processing Record 6 of Set 3 | romny
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=shahganj
# Processing Record 7 of Set 3 | shahganj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=vardo
# Processing Record 8 of Set 3 | vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=barrow
# Processing Record 9 of Set 3 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=belushya+guba
# Processing Record 10 of Set 3 | belushya guba
# 'coord'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=batticaloa
# Processing Record 11 of Set 3 | batticaloa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=tikrit
# Processing Record 12 of Set 3 | tikrit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=katsuura
# Processing Record 13 of Set 3 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=samarai
# Processing Record 14 of Set 3 | samarai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=faanui
# Processing Record 15 of Set 3 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=bolungarvik
# Processing Record 16 of Set 3 | bolungarvik
# 'coord'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=anchorage
# Processing Record 17 of Set 3 | anchorage
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=tasiilaq
# Processing Record 18 of Set 3 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=longonjo
# Processing Record 19 of Set 3 | longonjo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=hobart
# Processing Record 20 of Set 3 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=mayo
# Processing Record 21 of Set 3 | mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=makokou
# Processing Record 22 of Set 3 | makokou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=quatre+cocos
# Processing Record 23 of Set 3 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=viligili
# Processing Record 24 of Set 3 | viligili
# 'coord'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=faya
# Processing Record 25 of Set 3 | faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=hasaki
# Processing Record 26 of Set 3 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=tongliao
# Processing Record 27 of Set 3 | tongliao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=cordele
# Processing Record 28 of Set 3 | cordele
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=kalemie
# Processing Record 29 of Set 3 | kalemie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=vila+franca+do+campo
# Processing Record 30 of Set 3 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=burica
# Processing Record 31 of Set 3 | burica
# 'coord'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=pevek
# Processing Record 32 of Set 3 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=sao+felipe
# Processing Record 33 of Set 3 | sao felipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=labutta
# Processing Record 34 of Set 3 | labutta
# 'coord'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=areosa
# Processing Record 35 of Set 3 | areosa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=pisco
# Processing Record 36 of Set 3 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=sola
# Processing Record 37 of Set 3 | sola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=suhut
# Processing Record 38 of Set 3 | suhut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=henties+bay
# Processing Record 39 of Set 3 | henties bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=taoudenni
# Processing Record 40 of Set 3 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=bousso
# Processing Record 41 of Set 3 | bousso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=mehamn
# Processing Record 42 of Set 3 | mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=arrecife
# Processing Record 43 of Set 3 | arrecife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=nanortalik
# Processing Record 44 of Set 3 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=starkville
# Processing Record 45 of Set 3 | starkville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=usinsk
# Processing Record 46 of Set 3 | usinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=qandala
# Processing Record 47 of Set 3 | qandala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=loanda
# Processing Record 48 of Set 3 | loanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=vaini
# Processing Record 49 of Set 3 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=russell
# Processing Record 50 of Set 3 | russell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=laguna
# Processing Record 1 of Set 4 | laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=mar+del+plata
# Processing Record 2 of Set 4 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=doctor+pedro+p.+pena
# Processing Record 3 of Set 4 | doctor pedro p. pena
# 'coord'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=ahipara
# Processing Record 4 of Set 4 | ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=berlevag
# Processing Record 5 of Set 4 | berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=anadyr
# Processing Record 6 of Set 4 | anadyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=mandiana
# Processing Record 7 of Set 4 | mandiana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=ponta+do+sol
# Processing Record 8 of Set 4 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=waipawa
# Processing Record 9 of Set 4 | waipawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=taolanaro
# Processing Record 10 of Set 4 | taolanaro
# 'coord'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=padang
# Processing Record 11 of Set 4 | padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=severo-kurilsk
# Processing Record 12 of Set 4 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=margate
# Processing Record 13 of Set 4 | margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=diffa
# Processing Record 14 of Set 4 | diffa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=jalu
# Processing Record 15 of Set 4 | jalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=veraval
# Processing Record 16 of Set 4 | veraval
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=tuktoyaktuk
# Processing Record 17 of Set 4 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=qaanaaq
# Processing Record 18 of Set 4 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=saint-philippe
# Processing Record 19 of Set 4 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=we
# Processing Record 20 of Set 4 | we
# 'coord'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=olafsvik
# Processing Record 21 of Set 4 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=road+town
# Processing Record 22 of Set 4 | road town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=guatire
# Processing Record 23 of Set 4 | guatire
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=haapiti
# Processing Record 24 of Set 4 | haapiti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=ksenyevka
# Processing Record 25 of Set 4 | ksenyevka
# 'coord'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=vestmanna
# Processing Record 26 of Set 4 | vestmanna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=samusu
# Processing Record 27 of Set 4 | samusu
# 'coord'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=sobolevo
# Processing Record 28 of Set 4 | sobolevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=trincomalee
# Processing Record 29 of Set 4 | trincomalee
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=suez
# Processing Record 30 of Set 4 | suez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=amderma
# Processing Record 31 of Set 4 | amderma
# 'coord'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=ribeira+grande
# Processing Record 32 of Set 4 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=springfield
# Processing Record 33 of Set 4 | springfield
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=norman+wells
# Processing Record 34 of Set 4 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=dickinson
# Processing Record 35 of Set 4 | dickinson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=lata
# Processing Record 36 of Set 4 | lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=turukhansk
# Processing Record 37 of Set 4 | turukhansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=aksarka
# Processing Record 38 of Set 4 | aksarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=hofn
# Processing Record 39 of Set 4 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=evensk
# Processing Record 40 of Set 4 | evensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=clyde+river
# Processing Record 41 of Set 4 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=mount+gambier
# Processing Record 42 of Set 4 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=east+moline
# Processing Record 43 of Set 4 | east moline
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=tsihombe
# Processing Record 44 of Set 4 | tsihombe
# 'coord'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=mecca
# Processing Record 45 of Set 4 | mecca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=haines+junction
# Processing Record 46 of Set 4 | haines junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=upernavik
# Processing Record 47 of Set 4 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=mys+shmidta
# Processing Record 48 of Set 4 | mys shmidta
# 'coord'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=ambilobe
# Processing Record 49 of Set 4 | ambilobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=kuytun
# Processing Record 50 of Set 4 | kuytun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=lodja
# Processing Record 1 of Set 5 | lodja
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=puerto+cabezas
# Processing Record 2 of Set 5 | puerto cabezas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=luangwa
# Processing Record 3 of Set 5 | luangwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=barra+patuca
# Processing Record 4 of Set 5 | barra patuca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=lavrentiya
# Processing Record 5 of Set 5 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=gejiu
# Processing Record 6 of Set 5 | gejiu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=necochea
# Processing Record 7 of Set 5 | necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=chumikan
# Processing Record 8 of Set 5 | chumikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=skibbereen
# Processing Record 9 of Set 5 | skibbereen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=baghdad
# Processing Record 10 of Set 5 | baghdad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=avarua
# Processing Record 11 of Set 5 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=kodiak
# Processing Record 12 of Set 5 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=kieta
# Processing Record 13 of Set 5 | kieta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=kaoma
# Processing Record 14 of Set 5 | kaoma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=ormara
# Processing Record 15 of Set 5 | ormara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=nouadhibou
# Processing Record 16 of Set 5 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=beringovskiy
# Processing Record 17 of Set 5 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=krasnorechenskiy
# Processing Record 18 of Set 5 | krasnorechenskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=kaeo
# Processing Record 19 of Set 5 | kaeo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=saleaula
# Processing Record 20 of Set 5 | saleaula
# 'coord'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=aguadilla
# Processing Record 21 of Set 5 | aguadilla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=xai-xai
# Processing Record 22 of Set 5 | xai-xai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=nizhneyansk
# Processing Record 23 of Set 5 | nizhneyansk
# 'coord'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=rondonopolis
# Processing Record 24 of Set 5 | rondonopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=lorengau
# Processing Record 25 of Set 5 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=mlonggo
# Processing Record 26 of Set 5 | mlonggo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=hami
# Processing Record 27 of Set 5 | hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=haimen
# Processing Record 28 of Set 5 | haimen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=sao+bento
# Processing Record 29 of Set 5 | sao bento
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=melton
# Processing Record 30 of Set 5 | melton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=maldonado
# Processing Record 31 of Set 5 | maldonado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=savannah+bight
# Processing Record 32 of Set 5 | savannah bight
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=alofi
# Processing Record 33 of Set 5 | alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=leshukonskoye
# Processing Record 34 of Set 5 | leshukonskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=nikolskoye
# Processing Record 35 of Set 5 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=maralal
# Processing Record 36 of Set 5 | maralal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=komsomolskiy
# Processing Record 37 of Set 5 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=naze
# Processing Record 38 of Set 5 | naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=mvuma
# Processing Record 39 of Set 5 | mvuma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=port+moresby
# Processing Record 40 of Set 5 | port moresby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=araouane
# Processing Record 41 of Set 5 | araouane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=lebu
# Processing Record 42 of Set 5 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=miri
# Processing Record 43 of Set 5 | miri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=bulbucata
# Processing Record 44 of Set 5 | bulbucata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=cacoal
# Processing Record 45 of Set 5 | cacoal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=sale
# Processing Record 46 of Set 5 | sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=grand+river+south+east
# Processing Record 47 of Set 5 | grand river south east
# 'coord'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=mubi
# Processing Record 48 of Set 5 | mubi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=dudinka
# Processing Record 49 of Set 5 | dudinka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=coihaique
# Processing Record 50 of Set 5 | coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=namibe
# Processing Record 1 of Set 6 | namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=falealupo
# Processing Record 2 of Set 6 | falealupo
# 'coord'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=ucluelet
# Processing Record 3 of Set 6 | ucluelet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=chekalin
# Processing Record 4 of Set 6 | chekalin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=marathon
# Processing Record 5 of Set 6 | marathon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=goderich
# Processing Record 6 of Set 6 | goderich
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=collie
# Processing Record 7 of Set 6 | collie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=sept-iles
# Processing Record 8 of Set 6 | sept-iles
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=nalut
# Processing Record 9 of Set 6 | nalut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=hithadhoo
# Processing Record 10 of Set 6 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=rivadavia
# Processing Record 11 of Set 6 | rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=san+patricio
# Processing Record 12 of Set 6 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=karratha
# Processing Record 13 of Set 6 | karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=marawi
# Processing Record 14 of Set 6 | marawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=saint+peter
# Processing Record 15 of Set 6 | saint peter
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=collierville
# Processing Record 16 of Set 6 | collierville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=bandarbeyla
# Processing Record 17 of Set 6 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=asmar
# Processing Record 18 of Set 6 | asmar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=prerov
# Processing Record 19 of Set 6 | prerov
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=wahran
# Processing Record 20 of Set 6 | wahran
# 'coord'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=saint-pierre
# Processing Record 21 of Set 6 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=nadbai
# Processing Record 22 of Set 6 | nadbai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=raahe
# Processing Record 23 of Set 6 | raahe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=flin+flon
# Processing Record 24 of Set 6 | flin flon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=nsoko
# Processing Record 25 of Set 6 | nsoko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=sawankhalok
# Processing Record 26 of Set 6 | sawankhalok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=bubaque
# Processing Record 27 of Set 6 | bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=chuy
# Processing Record 28 of Set 6 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=birnin+kebbi
# Processing Record 29 of Set 6 | birnin kebbi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=ondorhaan
# Processing Record 30 of Set 6 | ondorhaan
# 'coord'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=cabo+san+lucas
# Processing Record 31 of Set 6 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=kruisfontein
# Processing Record 32 of Set 6 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=sinnamary
# Processing Record 33 of Set 6 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=tommot
# Processing Record 34 of Set 6 | tommot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=petropavlovsk-kamchatskiy
# Processing Record 35 of Set 6 | petropavlovsk-kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=kismayo
# Processing Record 36 of Set 6 | kismayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=portland
# Processing Record 37 of Set 6 | portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=umm+durman
# Processing Record 38 of Set 6 | umm durman
# 'coord'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=dongning
# Processing Record 39 of Set 6 | dongning
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=ayoquezco
# Processing Record 40 of Set 6 | ayoquezco
# 'coord'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=yarmouth
# Processing Record 41 of Set 6 | yarmouth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=ariquemes
# Processing Record 42 of Set 6 | ariquemes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=rundu
# Processing Record 43 of Set 6 | rundu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=labuhan
# Processing Record 44 of Set 6 | labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=maksatikha
# Processing Record 45 of Set 6 | maksatikha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=coquimbo
# Processing Record 46 of Set 6 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=cidreira
# Processing Record 47 of Set 6 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=alice+springs
# Processing Record 48 of Set 6 | alice springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=kavieng
# Processing Record 49 of Set 6 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=ales
# Processing Record 50 of Set 6 | ales
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=baruun-urt
# Processing Record 1 of Set 7 | baruun-urt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=codrington
# Processing Record 2 of Set 7 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=sao+joao+da+barra
# Processing Record 3 of Set 7 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=tiksi
# Processing Record 4 of Set 7 | tiksi
# ...
# Processing Record 9 of Set 13 | inverell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=sangar
# Processing Record 10 of Set 13 | sangar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=sikasso
# Processing Record 11 of Set 13 | sikasso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=chama
# Processing Record 12 of Set 13 | chama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=makakilo+city
# Processing Record 13 of Set 13 | makakilo city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=havoysund
# Processing Record 14 of Set 13 | havoysund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=petropavlivka
# Processing Record 15 of Set 13 | petropavlivka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=nhulunbuy
# Processing Record 16 of Set 13 | nhulunbuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=sohag
# Processing Record 17 of Set 13 | sohag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=tasbuget
# Processing Record 18 of Set 13 | tasbuget
# 'coord'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=jacksonville
# Processing Record 19 of Set 13 | jacksonville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=vanavara
# Processing Record 20 of Set 13 | vanavara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=straumen
# Processing Record 21 of Set 13 | straumen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=popondetta
# Processing Record 22 of Set 13 | popondetta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=whitehorse
# Processing Record 23 of Set 13 | whitehorse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=cururupu
# Processing Record 24 of Set 13 | cururupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=dhadar
# Processing Record 25 of Set 13 | dhadar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=novikovo
# Processing Record 26 of Set 13 | novikovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=kharp
# Processing Record 27 of Set 13 | kharp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=doha
# Processing Record 28 of Set 13 | doha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=dalvik
# Processing Record 29 of Set 13 | dalvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=shinuhayr
# Processing Record 30 of Set 13 | shinuhayr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=mananara
# Processing Record 31 of Set 13 | mananara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=okandja
# Processing Record 32 of Set 13 | okandja
# 'coord'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=vanino
# Processing Record 33 of Set 13 | vanino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=inhambane
# Processing Record 34 of Set 13 | inhambane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=usakos
# Processing Record 35 of Set 13 | usakos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=barawe
# Processing Record 36 of Set 13 | barawe
# 'coord'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=mildura
# Processing Record 37 of Set 13 | mildura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=longyearbyen
# Processing Record 38 of Set 13 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=moree
# Processing Record 39 of Set 13 | moree
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=general+roca
# Processing Record 40 of Set 13 | general roca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=santa+isabel+do+rio+negro
# Processing Record 41 of Set 13 | santa isabel do rio negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=tallahassee
# Processing Record 42 of Set 13 | tallahassee
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=karhal
# Processing Record 43 of Set 13 | karhal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=ciudad+bolivar
# Processing Record 44 of Set 13 | ciudad bolivar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=mackay
# Processing Record 45 of Set 13 | mackay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=tabas
# Processing Record 46 of Set 13 | tabas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=burns+lake
# Processing Record 47 of Set 13 | burns lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=atar
# Processing Record 48 of Set 13 | atar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=wanning
# Processing Record 49 of Set 13 | wanning
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=suffolk
# Processing Record 50 of Set 13 | suffolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=milkovo
# Processing Record 1 of Set 14 | milkovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=krasnoselkup
# Processing Record 2 of Set 14 | krasnoselkup
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=tumannyy
# Processing Record 3 of Set 14 | tumannyy
# 'coord'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=lagoa
# Processing Record 4 of Set 14 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=erenhot
# Processing Record 5 of Set 14 | erenhot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=hailar
# Processing Record 6 of Set 14 | hailar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=palanga
# Processing Record 7 of Set 14 | palanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=cardston
# Processing Record 8 of Set 14 | cardston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=port+hawkesbury
# Processing Record 9 of Set 14 | port hawkesbury
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=dyersburg
# Processing Record 10 of Set 14 | dyersburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=sabratah
# Processing Record 11 of Set 14 | sabratah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=molepolole
# Processing Record 12 of Set 14 | molepolole
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=horki
# Processing Record 13 of Set 14 | horki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=andapa
# Processing Record 14 of Set 14 | andapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=ziebice
# Processing Record 15 of Set 14 | ziebice
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=moron
# Processing Record 16 of Set 14 | moron
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=juiz+de+fora
# Processing Record 17 of Set 14 | juiz de fora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=abu+zabad
# Processing Record 18 of Set 14 | abu zabad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=chagda
# Processing Record 19 of Set 14 | chagda
# 'coord'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=borogontsy
# Processing Record 20 of Set 14 | borogontsy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=uyemskiy
# Processing Record 21 of Set 14 | uyemskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=markova
# Processing Record 22 of Set 14 | markova
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=cheremukhovo
# Processing Record 23 of Set 14 | cheremukhovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=iiyama
# Processing Record 24 of Set 14 | iiyama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=trzebiatow
# Processing Record 25 of Set 14 | trzebiatow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=nova+russas
# Processing Record 26 of Set 14 | nova russas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=nguiu
# Processing Record 27 of Set 14 | nguiu
# 'coord'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=qaqortoq
# Processing Record 28 of Set 14 | qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=songea
# Processing Record 29 of Set 14 | songea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=novoselytsya
# Processing Record 30 of Set 14 | novoselytsya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=grindavik
# Processing Record 31 of Set 14 | grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=ocho+rios
# Processing Record 32 of Set 14 | ocho rios
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=hervey+bay
# Processing Record 33 of Set 14 | hervey bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=tsabong
# Processing Record 34 of Set 14 | tsabong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=plettenberg+bay
# Processing Record 35 of Set 14 | plettenberg bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=longhua
# Processing Record 36 of Set 14 | longhua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=grimari
# Processing Record 37 of Set 14 | grimari
# 'coord'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=naifaru
# Processing Record 38 of Set 14 | naifaru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=flinders
# Processing Record 39 of Set 14 | flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=bathurst
# Processing Record 40 of Set 14 | bathurst
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=sao+jose+da+coroa+grande
# Processing Record 41 of Set 14 | sao jose da coroa grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=tsarychanka
# Processing Record 42 of Set 14 | tsarychanka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=bonoua
# Processing Record 43 of Set 14 | bonoua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=pisz
# Processing Record 44 of Set 14 | pisz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=ketchikan
# Processing Record 45 of Set 14 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=itarantim
# Processing Record 46 of Set 14 | itarantim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=inirida
# Processing Record 47 of Set 14 | inirida
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=lermontovka
# Processing Record 48 of Set 14 | lermontovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=huilong
# Processing Record 49 of Set 14 | huilong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=kvarkeno
# Processing Record 50 of Set 14 | kvarkeno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=nabire
# Processing Record 1 of Set 15 | nabire
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=lusambo
# Processing Record 2 of Set 15 | lusambo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=mao
# Processing Record 3 of Set 15 | mao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=topeka
# Processing Record 4 of Set 15 | topeka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=boissevain
# Processing Record 5 of Set 15 | boissevain
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=dalnerechensk
# Processing Record 6 of Set 15 | dalnerechensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=jumla
# Processing Record 7 of Set 15 | jumla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=baykit
# Processing Record 8 of Set 15 | baykit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=meulaboh
# Processing Record 9 of Set 15 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1a23d3a37e7ddea421b08fd0d9d8241&q=mikhaylov
# Processing Record 10 of Set 15 | mikhaylov
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Kahului      US  20.8947 -156.4700     78.80        61          40
# 1    Srednekolymsk      RU  67.4500  153.6833    -21.32        99          76
# 2           Hohhot      CN  40.8106  111.6522     32.00        47           0
# 3       Muravlenko      RU  63.7898   74.5230     28.63        97         100
# 4          Ushuaia      AR -54.8000  -68.3000     39.20        75          90
# 5     Richards Bay      ZA -28.7830   32.0377     72.03        59          86
# 6      Kloulklubed      PW   7.0419  134.2556     77.00        88          75
# 7           Albany      US  42.6001  -73.9662     52.00        13          14
# 8  Arraial Do Cabo      BR -22.9661  -42.0278     82.40        69          20
# 9        Carnarvon      AU -24.8667  113.6333     77.00        83           0
#
#    Wind Speed Current Description
# 0       17.27    scattered clouds
# 1        2.73       broken clouds
# 2        2.24           clear sky
# 3        7.74     overcast clouds
# 4       26.46          light snow
# 5       11.41     overcast clouds
# 6        4.61       broken clouds
# 7        7.67          few clouds
# 8        9.22          few clouds
# 9       12.66           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file)
